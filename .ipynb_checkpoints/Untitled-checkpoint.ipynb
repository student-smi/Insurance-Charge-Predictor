# %%
import numpy as np

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
np.sum(s ,axis=0)
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
s[0:3,0:3]
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
data.shape
# Out:
# (5, 3)

# %%
data[:,1]
# Out:
# array([85, 92, 76, 65, 90])

# %%
np.max(data[:,2])
# Out:
# np.int64(95)

# %%
data[data[:,1] > 90]
# Out:
# array([[19, 92, 88]])

# %%
data[:,0] += 5

# %%
data
# Out:
# array([[28, 85, 78],
#        [29, 92, 88],
#        [27, 76, 95],
#        [28, 65, 70],
#        [30, 90, 85]])

# %%
import numpy as np
import pandas as pd

# %%
label = ['a' , 'b' , 'c']
my_list = [10,20,30]
arr = np.array([11,22,33])
dis = { 1 :10 , 2 : 20 ,3 : 30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "name"  : ["smit" , "riyaa" , "nishaa" ,"krishaa"],
    "age"   : [18,18,25,18]
    
 }

# %%
pd.Series(dis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.Series(dis)
#
# NameError: name 'dis' is not defined

# %%
dt = pd.DataFrame(data)
dt
# Out:
#       name  age
# 0     smit   18
# 1    riyaa   18
# 2   nishaa   25
# 3  krishaa   18

# %%
data_list = [
    ["smit" , 18 , "gujrat"],
    ["riyaa" , 19 , "surat"]
]

column = ["name", "age" , "city"]

# %%
pd.DataFrame(data_list , columns=column)
# Out:
#     name  age    city
# 0   smit   18  gujrat
# 1  riyaa   19   surat

# %%
dt[["name" ,"age"]]
# Out:
#       name  age
# 0     smit   18
# 1    riyaa   18
# 2   nishaa   25
# 3  krishaa   18

# %%
dt["role"] = ['ceo' , 'cs' , 'ca' , "cfo"]

# %%
dt
# Out:
#       name  age role
# 0     smit   18  ceo
# 1    riyaa   18   cs
# 2   nishaa   25   ca
# 3  krishaa   18  cfo

# %%
dt.loc[[0 ,1]]
# Out:
#     name  age role
# 0   smit   18  ceo
# 1  riyaa   18   cs

# %%
dt.loc[[1,2]][['name']]
# Out:
#      name
# 1   riyaa
# 2  nishaa

# %%
dt[dt["age"]> 18]
# Out:
#      name  age role
# 2  nishaa   25   ca

# %%
dt[(dt['age'] == 18) & (dt["role"] == "ceo")]
# Out:
#    name  age role
# 0  smit   18  ceo

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df1 = pd.DataFrame(data)
df1
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df1.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
value = { "a" : 18 , "b" : 19 , "c" : 19 , "D" : 80}
df1.fillna(value=value)
# Out:
#      A  B    C     D
# 0  1.0  1  1.0   1.0
# 1  2.0  2  2.0  80.0
# 2  NaN  3  3.0  80.0
# 3  4.0  4  NaN  80.0
# 4  5.0  5  NaN   5.0

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

employees
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees, salaries , on="employee_id" ,how="right")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %%
df1 = pd.DataFrame({
    "smmmit" , "eaj"
} , index= [1,2] , columns=['name'])

# %%
df2 = pd.DataFrame({
    "rekha" , "mina"
} , index= [1,2] , columns=['name'])

# %%
df1.join(df2 , how="outer")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df1.join(df2 , how="outer")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:10784, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10774     if how == "cross":
#   10775         return merge(
#   10776             self,
#   10777             other,
#    (...)  10782             validate=validate,
#   10783         )
# > 10784     return merge(
#   10785         self,
#   10786         other,
#   10787         left_on=on,
#   10788         how=how,
#   10789         left_index=on is None,
#   10790         right_index=True,
#   10791         suffixes=(lsuffix, rsuffix),
#   10792         sort=sort,
#   10793         validate=validate,
#   10794     )
#   10795 else:
#   10796     if on is not None:
#
# ...

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}

# %%
dp = pd.DataFrame(data)

# %%
dp.groupby('Category')['Sales'].sum()
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
dp.groupby(['Store' , 'Category'])['Sales'].sum()
# Out:
# Store  Category
# S1     A           220
#        B           500
# S2     A           350
#        B           430
# Name: Sales, dtype: int64

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    832     21   John  January      Q1
# 1  2023-01-02       B   West    267     24   Mary  January      Q1
# 2  2023-01-03       C  North    777     95    Bob  January      Q1
# 3  2023-01-04       D  South    627     20  Alice  January      Q1
# 4  2023-01-05       A   East    973     80   John  January      Q1
# 5  2023-01-06       B   West    393     39   Mary  January      Q1
# 6  2023-01-07       C  North    594     99    Bob  January      Q1
# 7  2023-01-08       D  South    188     76  Alice  January      Q1
# 8  2023-01-09       A   East    695     19   John  January      Q1
# 9  2023-01-10       B   West    415     19   Mary  January      Q1
# 10 2023-01-11       C  North    986     21    Bob  January      Q1
# 11 2023-01-12       D  South    371     32  Alice  January      Q1
# 12 2023-01-13       A   East    383     78   John  January      Q1
# ...

# %%
pd.pivot_table(df, values="Sales" ,index="Region" ,columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     616.0    NaN    NaN    NaN
# North      NaN    NaN  664.2    NaN
# South      NaN    NaN    NaN  424.8
# West       NaN  470.2    NaN    NaN

# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
def su(x):
    return x**2

# %%
df1["C"]  = df1["C"].apply(su)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1["C"]  = df1["C"].apply(su)
#
# NameError: name 'df1' is not defined

# %%
df1
# Out:
#    A   B            C
# 0  1  10    100000000
# 1  2  20   1600000000
# 2  3  30   8100000000
# 3  4  40  25600000000
# 4  5  50  62500000000

# %%
df =pd.read_csv('anime.csv')
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.loc[1]['Title']
# Out:
# 'Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members'

# %%
def fectch_episode(title):
    check = False
    data = ""
    for i in title:
        
    
        if i == ")":
            check =False
            return data
            break
        if i == "(":
            check = True

        if check == True: 
            data =data + i

# %%
 df["episode"] = df["Title"].apply(fectch_episode)

# %%
df
# Out:
#     Rank                                              Title  Score   episode
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10   (64 eps
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07   (24 eps
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06   (13 eps
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06   (51 eps
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05   (10 eps
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04   (51 eps
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04    (1 eps
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04  (148 eps
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04   (13 eps
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03   (13 eps
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03    (2 eps
# ...

# %%
df["episode"] = df["episode"].str.replace( " eps" , " " ).replace("(" , " ")

# %%
df["episode"] = df["episode"].str.replace("(" , " ")

# %%
df["episode"] = df["episode"].astype(int)

# %%
df.head()
# Out:
#    Rank                                              Title  Score  episode
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10

# %%
def fetch_time(x):
    data = ""
    for i in range(len(x)):
        if x[i] == ")":
            for j in range (i+1 , i+20):
                data =data + x[j]

            return data

# %%
df["time"] = df["Title"].apply(fetch_time)

# %%
df.head()
# Out:
#    Rank                                              Title  Score  episode  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10
#
#                   time
# 0  Apr 2009 - Jul 2010
# 1  Apr 2011 - Sep 2011
# 2  Oct 2022 - Dec 2022
# 3  Apr 2015 - Mar 2016
# 4  Apr 2019 - Jul 2019

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

df['Months'] = df['time'].apply(calculate_total_months)

# %%
df
# Out:
#     Rank                                              Title  Score  episode  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04       51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04        1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04      148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04       13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03       13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03        2
# ...

# %%
df.head()
# Out:
#    Rank                                              Title  Score  episode  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10
#
#                   time  Months
# 0  Apr 2009 - Jul 2010      16
# 1  Apr 2011 - Sep 2011       6
# 2  Oct 2022 - Dec 2022       3
# 3  Apr 2015 - Mar 2016      12
# 4  Apr 2019 - Jul 2019       4

# %%
df[df["Months"] == df["Months"].max()]["Title"]
# Out:
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# Name: Title, dtype: object

# %%
df[df["Months"] == df["Months"].max()]["Title"]
# Out:
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# Name: Title, dtype: object

# %%
df[df["episode"] == df["episode"].max()].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(cls, axis)
#     579             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580         except KeyError:
# --> 581             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21584\1244420750.py in ?()
# ----> 1 df[df["episode"] == df["episode"].max(5)]
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py in ?(self, axis, skipna, numeric_only, **kwargs)
#    6534         skipna: bool = True,
#    6535         numeric_only: bool = False,
#    6536         **kwargs,
#    6537     ):
# ...

# %%
df.sort_values("episode", ascending=False).head(5)
# Out:
#     Rank                                              Title  Score  episode  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94      201
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04      148
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02      110
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...   8.76       75
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87       74
#
#                    time  Months
# 15  Apr 2006 - Mar 2010      48
# 7   Oct 2011 - Sep 2014      36
# 11  Jan 1988 - Mar 1997     111
# 42  Oct 2000 - Mar 2002      18
# 24  Apr 2004 - Sep 2005      18

# %%
df1 = pd.read_csv('Countries.csv')
df1.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df1[df1["population"] == df1["population"].max()]
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %%
df1[df1["population"] == df1["population"].min()]
# Out:
#     country country_long           currency capital_city     region continent  \
# 179  Tuvalu       Tuvalu  Australian dollar     Funafuti  Polynesia   Oceania
#
#       demonym  latitude  longitude  agricultural_land  ...  population  \
# 179  Tuvaluan      -8.0      178.0               18.0  ...       11312
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 179                        6.25              3900              7412    0.0
#
#      democracy_score  democracy_type  median_age  political_leader  \
# 179              0.0         Unknown        21.0     Kausea Natano
#
#               title
# 179  Prime Minister
#
# [1 rows x 64 columns]

# %%
df1.sort_values(by="democracy_score" , ascending=False , inplace=True)

# %%
df1.head()
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df1[df1['population' == df1['population'].nlargest(2).iloc[0]]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: np.False_
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ...

# %%
df1[df1['political_leader'].isna()]['country']
# Out:
# 27                         Cabo Verde
# 172                       Timor-Leste
# 151                   Slovak Republic
# 190                West Bank and Gaza
# 161    St. Vincent and the Grenadines
# 159               St. Kitts and Nevis
# 160                         St. Lucia
# Name: country, dtype: object

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5 , 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x **2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel("this is x label")
plt.ylabel("this is y label")
# Out:
# Text(0, 0.5, 'this is y label')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.scatter(x,y )

# %%
import seaborn as sbn
import pandas as pd 
import numpy as np

# %%
df =sbn.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sbn.displot(df['total_bill'])

# %%
sbn.pairplot(df , hue="sex")

# %%
sbn.countplot(x=df['sex'] , hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sbn.boxplot(x='tip' ,y='day' ,data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
ft = sbn.load_dataset('flights')
ft
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install cufflinks
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68559 sha256=7cea57b89d3213fd6c0fb203c65c6f9ccff52e4257876786ef39c0fa79057a37
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\13\bc\65\1ac45445dba1052b5e837dc49f5282c8cb2f934ae9e6f62f0e
# Successfully built cufflinks
# ...
#
#    ---------------------------------------- 2/2 [cufflinks]
#
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 


from plotly.offline import iplot
import matplotlib.pyplot as mt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = pd.read_csv('IPL.csv')
df1.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df1.shape
# Out:
# (74, 20)

# %%
df1.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
most_wins =df1['match_winner'].value_counts()

# %%
sns.barplot(x=most_wins.index , y=most_wins.values)
# Out:
# <Axes: xlabel='match_winner'>

# %%
sns.countplot(df1['won_by'])
# Out:
# <Axes: xlabel='count', ylabel='won_by'>

# %%
count = df1['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(y=count.index , x=count.values)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
df1.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
venue = df1['venue'].value_counts()
venue
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y=venue.index , x= venue.values)
# Out:
# <Axes: ylabel='venue'>

# %%
df1[df1['won_by'] == "Runs"].sort_values( by="margin" , ascending=False)[['won_by', "margin"]].head(5)
# Out:
#    won_by  margin
# 54   Runs      91
# 52   Runs      75
# 53   Runs      67
# 56   Runs      62
# 4    Runs      61
